# %% [markdown]
# <a href="https://colab.research.google.com/github/1limehanabi/CS114.O21.KHCL/LAB01/blob/main/CS114_2024_DigitClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MOUNTING TO DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # MÔ TẢ BÀI TOÁN
#
# - Input: Chữ số viết tay
# - Output: Kết quả nhận dạng
#
# Tham khảo: https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-from-scratch-for-mnist-handwritten-digit-classification/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MNIST Handwritten Digit Classification Dataset
#
# - Các ảnh greyscale có kích thước 28x28

# %%
from tensorflow.keras.datasets import mnist
from matplotlib import pyplot as plt

# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()

# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# plot first few images
for i in range(9):
  # define subplot
  plt.subplot(330 + 1 + i)
  # plot raw pixel data
  plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
  # show the figure
  plt.show()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
from numpy import mean
from numpy import std
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from numpy import argmax
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# %% [markdown]
# ## Load Dataset
#
# - we know that the images are all pre-aligned (e.g. each image only contains a hand-drawn digit), that the images all have the same square size of 28×28 pixels, and that the images are grayscale. Therefore, we can load the images and reshape the data arrays to have a single color channel.
# - a one hot encoding for the class element of each sample, transforming the integer into a 10 element binary vector with a 1 for the index of the class value, and 0 values for all other classes

# %%
def load_dataset():
  # load dataset
  (trainX, trainY), (testX, testY) = mnist.load_data()

  # reshape dataset to have a single channel
  trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
  testX = testX.reshape((testX.shape[0], 28, 28, 1))

  # one hot encode target values
  trainY = to_categorical(trainY)
  testY = to_categorical(testY)
  return trainX, trainY, testX, testY

# %% [markdown]
# ## Prepare Pixel Data
#
# - We know that the pixel values for each image in the dataset are unsigned integers in the range between black and white, or 0 and 255.
#
# - We do not know the best way to scale the pixel values for modeling, but we know that some scaling will be required.
#
# - A good starting point is to normalize the pixel values of grayscale images, e.g. rescale them to the range [0,1]. This involves first converting the data type from unsigned integers to floats, then dividing the pixel values by the maximum value.

# %%
def prep_pixels(train, test):
  # convert from integers to floats
  train_norm = train.astype('float32')
  test_norm = test.astype('float32')

  # normalize to range 0-1
  train_norm = train_norm / 255.0
  test_norm = test_norm / 255.0

  # return normalized images
  return train_norm, test_norm

# %% [markdown]
# ## Define Model

# %%
def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(10, activation='softmax'))

  # compile model
  opt = SGD(learning_rate=0.01, momentum=0.9)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

  return model

# %% [markdown]
# ## Evaluate Model

# %%
# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
  scores, histories = list(), list()

  # prepare cross validation
  kfold = KFold(n_folds, shuffle=True, random_state=1)

  # enumerate splits
  for train_ix, test_ix in kfold.split(dataX):

    # define model
    model = define_model()

    # select rows for train and test
    trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]

    # fit model
    history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=0)

    # evaluate model
    _, acc = model.evaluate(testX, testY, verbose=0)
    print('> %.3f' % (acc * 100.0))

    # stores scores
    scores.append(acc)
    histories.append(history)

  return scores, histories

# %% [markdown]
# ## Present Results

# %%
def summarize_diagnostics(histories):
  for i in range(len(histories)):
    # plot loss
    plt.subplot(2, 1, 1)
    plt.title('Cross Entropy Loss')
    plt.plot(histories[i].history['loss'], color='blue', label='train')
    plt.plot(histories[i].history['val_loss'], color='orange', label='test')

    # plot accuracy
    plt.subplot(2, 1, 2)
    plt.title('Classification Accuracy')
    plt.plot(histories[i].history['accuracy'], color='blue', label='train')
    plt.plot(histories[i].history['val_accuracy'], color='orange', label='test')
    plt.show()

# %%
def summarize_performance(scores):
  # print summary
  print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))

  # box and whisker plots of results
  plt.boxplot(scores)
  plt.show()

# %%
def run_test_harness():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)

  # evaluate model
  scores, histories = evaluate_model(trainX, trainY)

  # learning curves
  summarize_diagnostics(histories)

  # summarize estimated performance
  summarize_performance(scores)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# > 98.600
# > 98.542
# > 98.550
# > 98.750
# > 98.667
# Accuracy: mean=98.622 std=0.078, n=5

# %% [markdown]
# ## Save Final Model

# %%
# run the test harness for evaluating a model
def run_test_harness2():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)
  # define model
  model = define_model()

  # fit model
  model.fit(trainX, trainY, epochs=10, batch_size=32, verbose=0)

  # save model
  model.save('final_model.keras')

# %% [markdown]
# ## Evaluate Final Model

# %%
run_test_harness2()

# %% [markdown]
# ## Make Prediction

# %%
def load_image2(filename):
  # load the image
  img = load_img(filename, grayscale=True, target_size=(28, 28))

  # convert to array
  img = img_to_array(img)

  # reshape into a single sample with 1 channel
  img = img.reshape(1, 28, 28, 1)

  # prepare pixel data
  img = img.astype('float32')
  img = img / 255.0

  return img

# %%
from keras.preprocessing.image import load_img, img_to_array
import os

def load_images_from_folder(root_folder):
    root_folder = '/content/drive/MyDrive/data'
    images = []
    for root, dirs, files in os.walk(root_folder):
        for folder in dirs:
            student_folder = os.path.join(root, folder)
            print("Loading images from folder:", student_folder)
            for digit_folder in os.listdir(student_folder):
                digit_folder_path = os.path.join(student_folder, digit_folder)
                print("Loading images from subfolder:", digit_folder_path)

                # Check if digit_folder_path is a directory
                if os.path.isdir(digit_folder_path):
                    for image_file in os.listdir(digit_folder_path):
                        image_path = os.path.join(digit_folder_path, image_file)
                        img = load_image(image_path)
                        if img is not None:
                            images.append(img)
                        else:
                            print("Failed to load image:", image_path)
                else:
                    print("Skipping file:", digit_folder_path, "as it is not a directory")

    return images

def load_image(filename):
    try:
        # Check if the file exists
        if os.path.exists(filename):
            # load the image
            img = load_img(filename, color_mode="grayscale", target_size=(28, 28))

            # convert to array
            img = img_to_array(img)

            # reshape into a single sample with 1 channel
            img = img.reshape(1, 28, 28, 1)

            # prepare pixel data
            img = img.astype('float32')
            img = img / 255.0

            return img
        else:
            print("Image file does not exist:", filename)
            return None
    except Exception as e:
        print("Error loading image:", e)
        return None

root_folder = '/content/drive/MyDrive/data'
images = load_images_from_folder(root_folder)
print("Total loaded images:", len(images))
# Out:
# Loading images from folder: /content/drive/MyDrive/data/21522038
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/0
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/1
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/2
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/3
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/4
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/5
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/6
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/7
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/8
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/9
# Loading images from folder: /content/drive/MyDrive/data/21522270
# Loading images from subfolder: /content/drive/MyDrive/data/21522270/0
# Loading images from subfolder: /content/drive/MyDrive/data/21522270/1
# ...

# %%
from keras.models import load_model
from numpy import argmax

def run_example(root_folder):
    # load images
    images = load_images_from_folder(root_folder)

    # load model
    model = load_model('final_model.keras')

    # predict the class for each image
    for img in images:
        # predict the class
        predict_value = model.predict(img)

        # get the predicted digit
        digit = argmax(predict_value)
        print("Predicted digit:", digit)

# Đường dẫn đến thư mục chứa hình ảnh
root_folder = '/content/drive/MyDrive/data'

# Chạy hàm example
run_example(root_folder)
# Out:
# Loading images from folder: /content/drive/MyDrive/data/21522038
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/0
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/1
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/2
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/3
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/4
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/5
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/6
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/7
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/8
# Loading images from subfolder: /content/drive/MyDrive/data/21522038/9
# Loading images from folder: /content/drive/MyDrive/data/21522270
# Loading images from subfolder: /content/drive/MyDrive/data/21522270/0
# Loading images from subfolder: /content/drive/MyDrive/data/21522270/1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-74f950931a63> in <cell line: 1>()
# ----> 1 run_example()
#
# <ipython-input-40-d112cb79a7f1> in run_example()
#       2 def run_example():
#       3   # load the image
# ----> 4   img = load_images_from_folder()
#       5
#       6   # load model
#
# TypeError: load_images_from_folder() missing 1 required positional argument: 'root_folder'

# %%
# entry point, run the example
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4046643dfaac> in <cell line: 2>()
#       1 # entry point, run the example
# ----> 2 run_example()
#
# <ipython-input-23-215cdaf50c00> in run_example()
#       2 def run_example():
#       3   # load the image
# ----> 4   img = load_image()
#       5
#       6   # load model
#
# TypeError: load_image() missing 1 required positional argument: 'filename'
